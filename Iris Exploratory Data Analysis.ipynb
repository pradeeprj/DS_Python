# %% [markdown]
# It's a complete data exploration notebook to prepare your data for predictive analysis. Let's get started

# %%
#imported the relevant packages
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns #Statistical Data Visualization
import matplotlib.pyplot as plt

#import numpy as np
#import pandas as pd
#import seaborn as sns
#import matplotlib.pyplot as plt

# %%
# Let's import the data
iris=pd.read_csv("Iris.csv")

#iris=pd.read_csv('Iris.csv')

# %% [markdown]
# Now, let's check our data. It's very important for any data scientist to look at the data.

# %%
iris.head() #first 5 rows

#iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Identify the type of DATA for each column in the given dataset
# SepalLengthCm - Numerical (Discrete) (Upperlimit & lowerlimit)
# SepalWidthCm  - Numerical (Discrete)
# PetalLengthCm - Numerical (Discrete)
# PetalWidthCm  - Numerical (Discrete)
# Species ------- Categorical

# %%
#Figure out features and label
#Features : SepalLengthCm	SepalWidthCm	PetalLengthCm	PetalWidthCm
#Label: Species

# %%
#Identify which ML category does the use-case belong to?
#Label Type: Categorical ---> Supervised ----> Classification !!!!

# %%
# Identify which of the feature columns are more relevant to the Label. (Co-relation between label and respective feature)

# %%
iris.tail() #bottom 5 rows
#iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
#iris.info() #checking there are any inconsistencies/null-values in the data
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.1+ KB

# %% [markdown]
# I am little bit curious so I want to see first 10  rows to get a more clear understanding of the data.

# %%
iris.head(10) # first 10 rows
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# By looking at the data, we can understand that there are 3 types of species here.  Now we are going to exterminate unneeded column.

# %%
#iris.drop('Id',axis=1, inplace=True)
iris.drop('Id',axis=1, inplace=True)

# %%
# Check whether the dataset is a BALANCED DATASET or UNBALANCED DATASET !!!!
#(Q) How many data points for each class are present? 
#(or) How many flowers for each species are present?

iris["Species"].value_counts()
# balanced-dataset vs imbalanced datasets
#Iris is a balanced dataset as the number of data points for every class is 50.

#Iris-vir ---> 40
#Iris-se ----> 60
#Iris-ver ---> 50

#Incase your data is UNBALANCED, one way to make the data balanced is to perform any of the following steps:
# 1. Adaptive Boosting (Ada-Boost)
# 2. Gradient Boosting
# 3. Extreme Gradient Boosting (Xgboost)
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %% [markdown]
# Now, let's do some visual analysis

# %%
#2-D scatter plot:
#ALWAYS understand the axis: labels and scale.

#iris.plot(kind='scatter', x='SepalLengthCm', y='SepalWidthCm') ;
#plt.show()
iris.plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm');
plt.show()

#cannot make much sense out it. 
#What if we color the points by thier class-label/flower-type.

# %%
# 2-D Scatter plot with color-coding for each flower type/class.
# Here 'sns' corresponds to seaborn. 
#sns.set_style("whitegrid");
#sns.FacetGrid(iris, hue="Species", size=4) \
#   .map(plt.scatter, "SepalLengthCm", "SepalWidthCm") \
#   .add_legend();
#plt.show();

sns.set_style('whitegrid')
sns.FacetGrid(iris,hue='Species',height=5) \
    .map(plt.scatter,"SepalLengthCm","SepalWidthCm") \
    .add_legend()

plt.show()
    
# Notice that the blue points can be easily seperated 
# from red and green by drawing a line. 
# But red and green data points cannot be easily seperated.
# Can we draw multiple 2-D scatter plots for each combination of features?
# How many cobinations exist? 4C2 = 6.

# %%
# Writing Observations:
# 1. To distinguish Setosa, all we need is Seplength and seplwidth
# 2. Seperating Versi & Vir is a challenge . To tackle this lets try considering one more feature.. 

# Hence to create 3D graph we can use third party softwares or drivers
# plotly --- pandas

# %%
# pairwise scatter plot: Pair-Plot
# Dis-advantages: 
##Can be used when number of features are high.
##Cannot visualize higher dimensional patterns in 3-D and 4-D. 
#Only possible to view 2D patterns.
'''
plt.close();
sns.set_style("whitegrid");
sns.pairplot(iris, hue="Species", size=3);
plt.show()
'''

plt.close()
sns.set_style('whitegrid')
sns.pairplot(iris,hue='Species',height=3) \
    .add_legend()
plt.show()

# NOTE: the diagnol elements are PDFs for each feature. PDFs are expalined below.

# %%
# What about 1-D scatter plot using just one feature?
#1-D scatter plot of petal-length
'''
import numpy as np
iris_setosa = iris.loc[iris["Species"] == "Iris-setosa"];
iris_virginica = iris.loc[iris["Species"] == "Iris-virginica"];
iris_versicolor = iris.loc[iris["Species"] == "Iris-versicolor"];

#print(iris_setosa["petal_length"])
plt.plot(iris_setosa["PetalLengthCm"], np.zeros_like(iris_setosa['PetalLengthCm']), 'o')
plt.plot(iris_versicolor["PetalLengthCm"], np.zeros_like(iris_versicolor['PetalLengthCm']), 'o')
plt.plot(iris_virginica["PetalLengthCm"], np.zeros_like(iris_virginica['PetalLengthCm']), 'o')

plt.show()
'''
import numpy as np
iris_setosa = iris.loc[iris['Species'] == "Iris-setosa"];
iris_verginica = iris.loc[iris['Species'] == "Iris-virginica"];
iris_versicolor = iris.loc[iris['Species'] == 'Iris-versicolor'];
plt.plot(iris_setosa['PetalLengthCm'],np.zeros_like(iris_setosa['PetalLengthCm']),'o')
plt.plot(iris_verginica['PetalLengthCm'],np.zeros_like(iris_verginica['PetalLengthCm']), 'o')
plt.plot(iris_versicolor['PetalLengthCm'],np.zeros_like(iris_versicolor['PetalLengthCm']),'o')

plt.show()
#Disadvantages of 1-D scatter plot: Very hard to make sense as points 
#are overlapping a lot.
#Are there better ways of visualizing 1-D scatter plots?

# %%
#Histogram
'''
sns.FacetGrid(iris, hue="Species", size=5) \
   .map(sns.distplot, "PetalLengthCm") \
   .add_legend();
plt.show();
'''

plt.close()
sns.set_style('whitegrid')
sns.FacetGrid(iris,hue='Species',height=5) \
    .map(sns.distplot,"PetalLengthCm") \
    .add_legend()

plt.show()

# %%
#Graph with subplots
fig = iris[iris.Species=='Iris-setosa'].plot(kind= 'scatter', x='SepalLengthCm', y='SepalWidthCm', color = 'orange', label = 'setosa')
iris[iris.Species=='Iris-versicolor'].plot(kind='scatter',x='SepalLengthCm', y= 'SepalWidthCm', color = 'blue', label = 'versicolor', ax=fig)
iris[iris.Species=='Iris-virginica'].plot(kind='scatter', x= 'SepalLengthCm', y= 'SepalWidthCm', color = 'green', label='virginica',ax=fig)
fig.set_xlabel("Sepal Length")
fig.set_ylabel("Sepal Width")
fig.set_title("Sepal Length VS Width ")
fig=plt.gcf()
fig.set_size_inches(10,6)
plt.show()

# %% [markdown]
# The graph above gives the relationship between Sepal Length and Sepal Width, which is not very clear that's why I am going to plot another graph to explore the relationship between Petal Length and Petal Width

# %%
# Now let's visualize relationship between Petal Length and Petal Width
fig = iris[iris.Species== 'Iris-setosa'].plot(kind='scatter', x='PetalLengthCm', y='PetalWidthCm', color = 'orange', label = 'Setosa')
iris[iris.Species== 'Iris-versicolor'].plot(kind='scatter', x='PetalLengthCm', y= 'PetalWidthCm', color = 'blue', label = 'Versicolor', ax=fig)
iris[iris.Species== 'Iris-virginica'].plot(kind='scatter', x='PetalLengthCm', y= 'PetalWidthCm', color = 'green', label = 'Virginica', ax=fig)
fig.set_xlabel('Petal Length')
fig.set_ylabel('Petal Width')
fig.set_title('Petal Length VS Width')
fig=plt.gcf()
fig.set_size_inches(10,6)
plt.show()

# %%
#Same as above
'''
sns.set_style('whitegrid')
sns.FacetGrid(iris,hue='Species',height=10) \
    .map(plt.scatter,'PetalWidthCm','PetalLengthCm') \
    .add_legend()
plt.show()
'''

graph = iris[iris['Species'] == 'Iris-setosa'].plot(kind='scatter',x='PetalLengthCm',y='PetalWidthCm',color='Orange',label='Setosa')
iris[iris['Species'] == 'Iris-versicolor'].plot(kind='scatter',x='PetalLengthCm',y='PetalWidthCm',color='blue',label='Versicolor',ax=graph)
iris[iris['Species'] == 'Iris-virginica'].plot(kind='scatter',x='PetalLengthCm',y='PetalWidthCm',color='red',label='Verginica',ax=graph)
graph.set_xlabel('Petal Length')
graph.set_ylabel('Petal Width')
graph.set_title('Petal Length VS Width')
graph=plt.gcf()
graph.set_size_inches(10,6)
plt.show()
#iris[iris['Species'] == 'Iris-Versicolor']

# %% [markdown]
# We can see that the Petal Features are giving a better cluster division compared to the Sepal features. This is an indication that the Petals can help in better and accurate Predictions over the Sepal.

# %% [markdown]
# Now let us see how are the length and width are distributed

# %%
iris.hist(edgecolor='black', linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(12,6)
plt.show()

# %%
#Test
iris['PetalLengthCm'].plot(kind='hist',edgecolor='black',title='Petal Length')

# %%
# We can look at an individual feature in Seaborn through a boxplot
# X --- Label
# Y --- One of the best features (pair plot)

#Any data point beyond this whiskers will be extreme values (outliers)

#sns.boxplot(x="Species", y="PetalWidthCm", data=iris)
#or
sns.boxplot(data=iris,x="Species", y ='PetalLengthCm')

# %% [markdown]
# We can extend this plot by adding a layer of individual points on top of it. Let's try.

# %%
ax = sns.boxplot(x="Species", y="PetalLengthCm", data=iris)
ax = sns.stripplot(x="Species", y="PetalLengthCm", data=iris, jitter=True, edgecolor="gray") #We'll use jitter=True so that all the points don't fall in single vertical lines 
#above the species
#Saving the resulting axes as ax each time causes the resulting plot to be shown on top 
#of the previous axes

# %% [markdown]
# Now let us see how the length and width vary according to the species

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species',y='PetalLengthCm',data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='PetalWidthCm',data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='Species',y='SepalLengthCm',data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='SepalWidthCm',data=iris)
plt.show()

# %% [markdown]
# The violinplot shows density of the length and width in the species. The thinner part denotes that there is less density whereas the fatter part conveys higher density

# %%
#A final seaborn plot useful for looking at univariate relations is the kdeplot,
# it creates and visualizes a kernel density estimate of the underlying feature
sns.FacetGrid(iris, hue="Species", size=6) \
   .map(sns.kdeplot, "PetalLengthCm") \
   .add_legend()

# %% [markdown]
# Another useful seaborn plot is the pairplot, which shows the bivariate relation
# between each pair of features
# From the pairplot, we'll see that the Iris-setosa species is separataed from the other two across all feature combinations
# Let's see then,

# %%
#pairplot
sns.pairplot(iris, hue="Species", size=3)

# %% [markdown]
# The diagonal elements in a pairplot show the histogram by default
# We can update these elements to show other things, such as a kde

# %%
sns.pairplot(iris,hue="Species", size=3, diag_kind="kde")
